# %%
# Changing the stratication gradient and domain refinement

# %%
using Oceananigans
using Oceananigans.Units

for k in 1:3
    for i in 1:10
        grid = RectilinearGrid(CPU(), size = (k*160, k*32), extent = (10000meters, 500meters), topology = (Bounded, Flat, Bounded))
            
        model = NonhydrostaticModel(; grid,
                                          advection = WENO(; grid),
                                          coriolis = FPlane(latitude = 0),
                                          closure = AnisotropicMinimumDissipation(),
                                          buoyancy = SeawaterBuoyancy(constant_salinity = true),
                                          tracers = (:T, :S))


        T0 = 9
        
        set!(model, T = function (x,z) T0 + 0.01 * i * tanh((x - 7000 + 4 * z) / 500) end )
                
        simulation = Simulation(model; Δt = 50/k, stop_time = 1days)

        u, v, w = model.velocities
         
        outputs = (
                u  = @at((Center, Center, Center), u),
                v = @at((Center, Center, Center), v),
                w = @at((Center, Center, Center), w),
                Ro = @at((Center, Center, Center), (∂x(v)-∂y(u))/f),
                Ri = @at ((Center, Center, Center), (-g/T0)*∂z(T)/((∂z(u))^2+(∂z(v))^2))
        )
        simulation.output_writers[:fields] = NetCDFOutputWriter(model, merge(outputs, model.tracers),
                                                                 filename = string("../../data/without_coriolis/buoyancy_front_",k,"_", i,".nc"),
                                                                 schedule = TimeInterval(24minute),
                                                                 overwrite_existing = true)
                
        run!(simulation)    
    end
end
# Out:
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (1.524 seconds)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (32.659 ms).
# [ Info: Simulation is stopping after running for 26.464 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (17.362 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (26.925 ms).
# [ Info: Simulation is stopping after running for 25.658 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (22.405 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (30.174 ms).
# [ Info: Simulation is stopping after running for 26.253 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (17.218 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (27.166 ms).
# [ Info: Simulation is stopping after running for 25.820 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (17.390 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (27.303 ms).
# [ Info: Simulation is stopping after running for 25.843 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (18.250 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (27.570 ms).
# [ Info: Simulation is stopping after running for 26.565 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (23.535 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (32.269 ms).
# [ Info: Simulation is stopping after running for 28.437 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (24.627 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (36.739 ms).
# [ Info: Simulation is stopping after running for 25.484 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (17.674 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (33.054 ms).
# [ Info: Simulation is stopping after running for 24.949 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (17.327 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (26.751 ms).
# [ Info: Simulation is stopping after running for 25.701 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (849.470 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (105.559 ms).
# [ Info: Simulation is stopping after running for 3.229 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (60.168 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (109.224 ms).
# [ Info: Simulation is stopping after running for 3.381 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (81.153 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (109.916 ms).
# [ Info: Simulation is stopping after running for 3.212 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (61.399 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (104.796 ms).
# [ Info: Simulation is stopping after running for 3.183 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (56.335 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (112.618 ms).
# [ Info: Simulation is stopping after running for 3.198 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (57.069 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (104.545 ms).
# [ Info: Simulation is stopping after running for 3.171 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (57.091 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (108.275 ms).
# [ Info: time = 52140.0, iteration = 2100: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (56.249 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (104.472 ms).
# [ Info: time = 47180.0, iteration = 1900: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (58.711 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (108.404 ms).
# [ Info: time = 44690.0, iteration = 1800: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (58.538 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (106.448 ms).
# [ Info: time = 42210.0, iteration = 1700: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (894.225 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (227.709 ms).
# [ Info: Simulation is stopping after running for 10.682 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (126.462 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (232.214 ms).
# [ Info: Simulation is stopping after running for 10.201 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (117.818 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (225.739 ms).
# [ Info: Simulation is stopping after running for 10.205 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (122.180 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (238.073 ms).
# [ Info: Simulation is stopping after running for 10.586 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (117.214 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (225.562 ms).
# [ Info: Simulation is stopping after running for 10.213 minutes.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (118.377 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (231.034 ms).
# [ Info: time = 54629.9999999998, iteration = 3300: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (119.509 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (226.634 ms).
# [ Info: time = 49659.9999999999, iteration = 3000: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (122.386 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (240.996 ms).
# [ Info: time = 46346.66666666663, iteration = 2800: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (128.907 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (245.099 ms).
# [ Info: time = 11586.666666666664, iteration = 700: NaN found in field u. Stopping simulation.
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (122.180 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (233.393 ms).
# [ Info: time = 41386.66666666651, iteration = 2500: NaN found in field u. Stopping simulation.
