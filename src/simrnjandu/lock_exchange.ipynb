# %%
# Changing the stratication gradient and domain refinement

# %%
using Oceananigans
using Oceananigans.Units

for k in 1:3
    for i in 1:10
        grid = RectilinearGrid(CPU(), size = (k*160, k*32), extent = (10000meters, 500meters), topology = (Bounded, Flat, Bounded))
    
        model = NonhydrostaticModel(; grid,
                                  advection = WENO(; grid),
                                  coriolis = FPlane(latitude = 0),
                                  closure = AnisotropicMinimumDissipation(),
                                  buoyancy = SeawaterBuoyancy(constant_salinity = true),
                                  tracers = (:T, :S))
        set!(model, T = function (x,z) 9 + 0.05 * i * tanh((x - 7000 + 4 * z) / 500) end )
        
        simulation = Simulation(model; Δt = 50/k, stop_time = 1days)
        
        simulation.output_writers[:tracers] = NetCDFOutputWriter(model, model.tracers,
                                                               filename = string("../../data/buoyancy_front_",k,"_", i,".nc"),
                                                               schedule = TimeInterval(24minute),
                                                               overwrite_existing = true)
        
        run!(simulation)    
    end
end
# Out:
# ┌ Warning: Overwriting existing ./../../data/buoyancy_front_1_1.nc.
# └ @ Oceananigans.OutputWriters ~/.julia/packages/Oceananigans/86soN/src/OutputWriters/netcdf_output_writer.jl:359
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (16.283 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (26.456 ms).
# [ Info: Simulation is stopping after running for 23.583 seconds.
# [ Info: Simulation time 1 day equals or exceeds stop time 1 day.
# ┌ Warning: Overwriting existing ./../../data/buoyancy_front_1_2.nc.
# └ @ Oceananigans.OutputWriters ~/.julia/packages/Oceananigans/86soN/src/OutputWriters/netcdf_output_writer.jl:359
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (14.710 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (25.209 ms).
# [ Info: Simulation is stopping after running for 23.304 seconds.
# ...
